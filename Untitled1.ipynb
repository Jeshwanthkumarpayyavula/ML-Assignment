# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeshwanthkumarpayyavula/ML-Assignment/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Developed by: Jeshwanth Kumar
#Ref No:212223240114

# %% [markdown]
# # Q1. Create a scatter plot between cylinder vs Co2Emission (green color)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('/content/FuelConsumption.csv')

plt.scatter(df['CYLINDERS'], df['CO2EMISSIONS'], color='green')
plt.xlabel('CYLINDERS')
plt.ylabel('CO2 EMISSIONS')
plt.title('Scatter plot of Cylinders vs CO2 EMISSION')
plt.show()

# %% [markdown]
# # Q2. Using scatter plot compare data cylinder vs Co2Emission and Enginesize Vs Co2Emission using different colors

# %%
plt.scatter(df['CYLINDERS'], df['CO2EMISSIONS'], color='green')
plt.scatter(df['ENGINESIZE'], df['CO2EMISSIONS'], color='red')
plt.xlabel('Engine size or cylinders')
plt.ylabel('CO2 Emission')
plt.title('Scatter plot of Engine size and Cylinders vs CO2 Emission')
plt.show()

# %% [markdown]
# # Q3. Using scatter plot compare data cylinder vs Co2Emission and Enginesize Vs Co2Emission and FuelConsumption_comb Co2Emission using different colors

# %%
plt.scatter(df['CYLINDERS'], df['CO2EMISSIONS'], color='green')
plt.scatter(df['ENGINESIZE'], df['CO2EMISSIONS'], color='red')
plt.scatter(df['FUELCONSUMPTION_COMB'], df['CO2EMISSIONS'], color='blue')
plt.xlabel('Engine size, Cylinders or Fuel Consumption')
plt.ylabel('CO2 Emission')
plt.title('Scatter plot of Engine size, Cylinders and Fuel Consumption vs CO2 Emission')
plt.show()

# %% [markdown]
# # Q4.Train your model with independent variable as cylinder and dependent variable as CO2Emission

# %%
from sklearn import linear_model
X = df[['FUELCONSUMPTION_COMB']]
y = df['CO2EMISSIONS']
reg=linear_model.LinearRegression()

# %% [markdown]
# #Q5.Choose your desired model and train it

# %%
print("x_train\n",x_train)
print("tested values",y_test)
# Out:
# x_train
#        FUELCONSUMPTION_COMB
# 692                   14.5
# 45                    17.7
# 866                   10.7
# 255                    8.3
# 252                    7.5
# ...                    ...
# 1033                   6.9
# 763                   16.0
# 835                   11.7
# 559                   13.3
# 684                   11.4
#
# [984 rows x 1 columns]
# tested values 766    356
# 204    209
# 629    230
# 897    212
# 711    168
#       ...
# 718    235
# 712    166
# 413    186
# 535    253
# 857    161
# Name: CO2EMISSIONS, Length: 83, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=1/13,random_state=0)
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
print("Predicted values\n",y_pred)
print("Tested values\n",y_test)
# Out:
# Predicted values
#  [319.67970721 216.44401056 230.9615304  218.05706832 187.40897088
#  274.51408993 218.05706832 263.22268561 211.60483728 303.54912961
#  289.03160977 376.13672882 203.53954848 266.44880113 193.86120192
#  251.93128129 360.00615122 226.12235712 245.47905024 321.29276497
#  203.53954848 201.92649072 240.63987696 239.0268192  161.60004672
#  268.06185889 261.60962785 366.45838226 242.25293472 147.08252687
#  321.29276497 237.41376144 300.32301409 235.80070368 203.53954848
#  206.765664   276.12714769 224.50929936 235.80070368 235.80070368
#  198.7003752  198.7003752  211.60483728 185.79591312 277.74020545
#  208.37872176 251.93128129 195.47425968 416.46317282 321.29276497
#  306.77524513 360.00615122 272.90103217 159.98698896 230.9615304
#  195.47425968 268.06185889 180.95673984 250.31822353 216.44401056
#  214.8309528  213.21789504 227.73541488 366.45838226 253.54433905
#  279.35326321 318.06664945 301.93607185 214.8309528  156.76087344
# ...

# %% [markdown]
# #Q6.Make predictions and evaluate your model

# %%
plt.scatter(x_train,y_train,color="blue")
plt.plot(x_train,reg.predict(x_train),color="red")
plt.title("FUEL CONSUMPSION vs CO2Emissions (Training_Set)")
plt.xlabel("FUEL CONSUMPSION")
plt.ylabel("Co2Emissions")
plt.show()
